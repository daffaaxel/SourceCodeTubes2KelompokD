# %% [markdown]
# ## FOOD PRICES
# - Daffa Axel Kautsar Rangkuti
# - Bagus Tejomukti
# - Muhammad Naufal Regga Reviadi

# %% [markdown]
# 1. Importing Pandas, Matplotlib, dan OS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# 2. Deskripsi Data dan File
# - Data berformat .csv dan diambil dari file "Food Prices.csv"

# %%
# Membaca Food Prices.csv ke source code
fp = pd.read_csv("Food Prices.csv")
fp
# Out:
#        Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 0     Australia   2018       1      Bread                Loaf            2.20
# 1     Australia   2018       2      Bread                Loaf            2.20
# 2     Australia   2018       3      Bread                Loaf            2.20
# 3     Australia   2018       4      Bread                Loaf            2.21
# 4     Australia   2018       5      Bread                Loaf            2.21
# ...         ...    ...     ...        ...                 ...             ...
# 1195     Canada   2022       8   Potatoes                1 Kg            3.17
# 1196     Canada   2022       9   Potatoes                1 Kg            3.18
# 1197     Canada   2022      10   Potatoes                1 Kg            3.20
# 1198     Canada   2022      11   Potatoes                1 Kg            3.21
# 1199     Canada   2022      12   Potatoes                1 Kg            3.22
#
# ...

# %% [markdown]
# # Data Cleansing

# %% [markdown]
# Pada Data Food Prices, terdapat kesalahan pada kategori Unit of Measurements. Kesalahan tersebut terletak di beberapa data dengan Kategori Food Items Susu mendapatkan Unit of Measurements 1 kg, berbeda dengan data Kategori Susu lainnya yang mendapatkan Unit of Measurements nya adalah 1 L.
#
# Maka dari itu, kita harus bersihkan data tersebut dengan mengubah Unit of Measurements Susu menjadi sama semua yaitu 1 L.

# %% [markdown]
# - Memperbaiki Unit of Measurements Susu yang awalnya 1 kg menjadi 1L

# %%
# Membuat looping untuk replace data
for index in range(1020, 1080):
    if fp.loc[index, 'Unit of Measurement'] == '1 Kg':
        fp.at[index, 'Unit of Measurement'] = '1 L'

# Hasil Cleansing Data
print(fp.to_string())
# Out:
#           Country   Year   Month  Food Item  Unit of Measurement  Average Price  Currency   Price in USD  Availability  Quality
# 0        Australia   2018       1      Bread                Loaf            2.20       AUD          1.47              1     High
# 1        Australia   2018       2      Bread                Loaf            2.20       AUD          1.48              1     High
# 2        Australia   2018       3      Bread                Loaf            2.20       AUD          1.48              1     High
# 3        Australia   2018       4      Bread                Loaf            2.21       AUD          1.48              1     High
# 4        Australia   2018       5      Bread                Loaf            2.21       AUD          1.48              1     High
# 5        Australia   2018       6      Bread                Loaf            2.22       AUD          1.49              1     High
# ...

# %%
# Mengetahui banyaknya baris dan kolom data
print(f"Diketahui terdapat {fp.shape} dengan (baris,kolom)")

# Mengetahui ukuran data (baris x kolom)
print(f"Diketahui ukuran data sebesar {fp.size} sel")

# Mengetahui ukuran file (bytes)
size_bytes = os.stat("Food Prices.csv").st_size
print(f"Ukuran file data sebesar {size_bytes} bytes")
# Out:
# Diketahui terdapat (1200, 10) dengan (baris,kolom)
# Diketahui ukuran data sebesar 12000 sel
# Ukuran file data sebesar 62635 bytes

# %% [markdown]
# 3. Karakteristik Data

# %% [markdown]
# - Data Type setiap Kolom

# %%
# Mengetahui data type setiap kolom
fp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              1200 non-null   object
#  1   Year                 1200 non-null   int64
#  2   Month                1200 non-null   int64
#  3   Food Item            1200 non-null   object
#  4   Unit of Measurement  1200 non-null   object
#  5   Average Price        1200 non-null   float64
#  6   Currency             1200 non-null   object
#  7   Price in USD         1200 non-null   float64
#  8   Availability         1200 non-null   int64
#  9   Quality              1200 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# - Range Data

# %%
#Membuat variabel minimum dan maksimum
minimum = fp.min()
maximum = fp.max()

#Cari Minimum
minyear = minimum["Year "]
minmonth = minimum["Month "]
minavgprice = minimum['Average Price ']
minpriceus = minimum['Price in USD']
minavail = minimum['Availability ']

#Cari Maksimum
maxyear = maximum["Year "]
maxmonth = maximum["Month "]
maxavgprice = maximum['Average Price ']
maxpriceus = maximum['Price in USD']
maxavail = maximum['Availability ']

# Mengetahui range nilai data pada Kolom Year
print(f"Nilai data kolom Year berkisar dari {minimum["Year "]} sampai {maximum["Year "]}")

# Mengetahui range nilai data pada kolom Month
print(f"Nilai data kolom Month berkisar dari {minimum["Month "]} sampai {maximum["Month "]}")

# Mengetahui range nilai data pada kolom Average Price
print(f"Nilai data kolom Average Price berkisar dari {minimum['Average Price ']} sampai {maximum['Average Price ']}")

# Mengetahui range nilai data pada kolom Price in US
print(f"Nilai data kolom Price in US berkisar dari {minimum['Price in USD']} sampai {maximum['Price in USD']}")

# Mengetahui range nilai data pada kolom Availability
print(f"Nilai data kolom Availability berkisar dari {minimum['Availability ']} sampai {maximum['Availability ']}")
# Out:
# Nilai data kolom Year berkisar dari 2018 sampai 2022
# Nilai data kolom Month berkisar dari 1 sampai 12
# Nilai data kolom Average Price berkisar dari 1.22 sampai 421.43
# Nilai data kolom Price in US berkisar dari 0.69 sampai 4.03
# Nilai data kolom Availability berkisar dari 1 sampai 1

# %% [markdown]
# - Tabel Frekuensi

# %%
# Tabel Frekuensi Negara pada kolom Country
print(fp["Country "].value_counts())

print(" ")

# Tabel Frekuensi Tahun pada kolom Year
print(fp["Year "].value_counts())

print(" ")

# Tabel Frekuensi Bulan (dalam bentuk angka) pada kolom Month
print(fp["Month "].value_counts())

print(" ")

# Tabel Frekuensi Makanan pada kolom Food Item
print(fp["Food Item "].value_counts())

print(" ")

# Tabel Frekuensi satuan pengukuran pada kolom Unit of Measurement
print(fp["Unit of Measurement"].value_counts())

print(" ")

# Tabel Frekuensi Mata Uang pada kolom Currency
print(fp["Currency "].value_counts())

print(" ")

# Tabel Frekuensi Kualitas pada kolom Quality
print(fp["Quality "].value_counts())
# Out:
# Country
# Australia       240
# Sweden          240
# Japan           240
# South Africa    240
# Canada          240
# Name: count, dtype: int64
#
# Year
# 2018    240
# 2019    240
# 2020    240
# 2021    240
# 2022    240
# Name: count, dtype: int64
#
# Month
# 1     100
# 2     100
# 3     100
# 4     100
# 5     100
# 6     100
# 7     100
# 8     100
# 9     100
# 10    100
# 11    100
# 12    100
# Name: count, dtype: int64
#
# Food Item
# Bread       300
# Milk        300
# Eggs        300
# Potatoes    300
# Name: count, dtype: int64
#
# Unit of Measurement
# Loaf            300
# 1 L             300
# Carton of 12    300
# 1 Kg            300
# Name: count, dtype: int64
#
# Currency
# AUD     240
# Kr      240
# JPY     240
# ZAR     240
# CAD     240
# Name: count, dtype: int64
#
# Quality
# High      960
# Medium    240
# Name: count, dtype: int64

# %% [markdown]
# - Persentase Data Kosong

# %%
#Persentase Data Kosong
fp.isnull().mean()*100
# Out:
# Country                0.0
# Year                   0.0
# Month                  0.0
# Food Item              0.0
# Unit of Measurement    0.0
# Average Price          0.0
# Currency               0.0
# Price in USD           0.0
# Availability           0.0
# Quality                0.0
# dtype: float64

# %% [markdown]
# 4. Statistik Data

# %% [markdown]
# - Sorting Kolom

# %%
# 5 Harga Rata-Rata di data yang lebih sering muncul (frekuensi tertinggi)
print("5 Harga Rata-Rata yang lebih sering muncul (frekuensi tertinggi)")
print(fp["Average Price "].value_counts().head(5))

print(" ")

# 5 Harga USD di data yang lebih sering muncul (frekuensi tertinggi)
print("5 Harga USD yang lebih sering muncul (frekuensi tertinggi)")
fp["Price in USD"].value_counts().head(5)
# Out:
# 5 Harga Rata-Rata yang lebih sering muncul (frekuensi tertinggi)
# Average Price
# 3.26    12
# 3.75    10
# 2.97     7
# 3.04     7
# 2.98     7
# Name: count, dtype: int64
#
# 5 Harga USD yang lebih sering muncul (frekuensi tertinggi)
# Price in USD
# 1.39    26
# 1.38    25
# 1.60    20
# 2.19    17
# 0.88    15
# Name: count, dtype: int64

# %% [markdown]
# - Mencari Nilai Rata-Rata, Standar Deviasi, Persentil (25%,50%,75%),Ekstremum (nilai maksimum dan minimum)

# %%
fp.describe()
# Out:
#              Year        Month   Average Price   Price in USD  Availability
# count  1200.000000  1200.000000     1200.000000   1200.000000         1200.0
# mean   2020.000000     6.500000       59.129550      1.801842            1.0
# std       1.414803     3.453492      103.155832      0.725390            0.0
# min    2018.000000     1.000000        1.220000      0.690000            1.0
# 25%    2019.000000     3.750000        3.207500      1.170000            1.0
# 50%    2020.000000     6.500000       13.355000      1.680000            1.0
# 75%    2021.000000     9.250000       28.882500      2.320000            1.0
# max    2022.000000    12.000000      421.430000      4.030000            1.0

# %% [markdown]
# - Mencari Nilai Persentil 10% dan 90%

# %%
# Buat DataFrame yang berisi integer/float
data = {
    'Year': fp["Year "],
    'Month': fp["Month "],
    'Average Price': fp["Average Price "],
    'Price in USD': fp["Price in USD"],
    'Availability': fp["Availability "]
}

df = pd.DataFrame(data)
df

# Cari Persentil 10% dan 90%
quantiles = df.quantile([0.1, 0.9])
quantiles
# Out:
#        Year  Month  Average Price  Price in USD  Availability
# 0.1  2018.0    2.0          2.529          0.88           1.0
# 0.9  2022.0   11.0        212.051          2.89           1.0

# %% [markdown]
# - 5 data teratas

# %%
fp[:5]
# Out:
#     Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 0  Australia   2018       1      Bread                Loaf            2.20
# 1  Australia   2018       2      Bread                Loaf            2.20
# 2  Australia   2018       3      Bread                Loaf            2.20
# 3  Australia   2018       4      Bread                Loaf            2.21
# 4  Australia   2018       5      Bread                Loaf            2.21
#
#   Currency   Price in USD  Availability  Quality
# 0       AUD          1.47              1     High
# 1       AUD          1.48              1     High
# 2       AUD          1.48              1     High
# 3       AUD          1.48              1     High
# 4       AUD          1.48              1     High

# %% [markdown]
# - 5 data terbawah

# %%
fp.tail(5)
# Out:
#      Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 1195   Canada   2022       8   Potatoes                1 Kg            3.17
# 1196   Canada   2022       9   Potatoes                1 Kg            3.18
# 1197   Canada   2022      10   Potatoes                1 Kg            3.20
# 1198   Canada   2022      11   Potatoes                1 Kg            3.21
# 1199   Canada   2022      12   Potatoes                1 Kg            3.22
#
#      Currency   Price in USD  Availability  Quality
# 1195       CAD          2.41              1     High
# 1196       CAD          2.42              1     High
# 1197       CAD          2.43              1     High
# 1198       CAD          2.44              1     High
# 1199       CAD          2.45              1     High

# %% [markdown]
# - 5 data Harga Rata-Rata teratas

# %%
fp["Average Price "].head(5)
# Out:
# 0    2.20
# 1    2.20
# 2    2.20
# 3    2.21
# 4    2.21
# Name: Average Price , dtype: float64

# %% [markdown]
# - 5 data Harga Rata-Rata terbawah

# %%
fp["Average Price "].tail(5)
# Out:
# 1195    3.17
# 1196    3.18
# 1197    3.20
# 1198    3.21
# 1199    3.22
# Name: Average Price , dtype: float64

# %% [markdown]
# - 5 data Harga USD teratas

# %%
fp["Price in USD"].head(5)
# Out:
# 0    1.47
# 1    1.48
# 2    1.48
# 3    1.48
# 4    1.48
# Name: Price in USD, dtype: float64

# %% [markdown]
# - 5 data Harga USD terbawah

# %%
fp["Price in USD"].tail(5)
# Out:
# 1195    2.41
# 1196    2.42
# 1197    2.43
# 1198    2.44
# 1199    2.45
# Name: Price in USD, dtype: float64

# %% [markdown]
# - Data harga rata-rata roti di atas rata-rata

# %%
mean_priceavg = fp["Average Price "].mean()
fp.loc[(fp["Average Price "] > mean_priceavg) & (fp["Food Item "] == "Bread")]
# Out:
#     Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 480    Japan   2018       1      Bread                Loaf          186.39
# 481    Japan   2018       2      Bread                Loaf          186.87
# 482    Japan   2018       3      Bread                Loaf          187.35
# 483    Japan   2018       4      Bread                Loaf          187.83
# 484    Japan   2018       5      Bread                Loaf          188.31
# 485    Japan   2018       6      Bread                Loaf          188.79
# 486    Japan   2018       7      Bread                Loaf          189.27
# 487    Japan   2018       8      Bread                Loaf          189.75
# 488    Japan   2018       9      Bread                Loaf          190.23
# 489    Japan   2018      10      Bread                Loaf          190.71
# 490    Japan   2018      11      Bread                Loaf          191.19
# ...

# %% [markdown]
# - Data harga rata-rata susu di atas rata-rata

# %%
mean_priceavg = fp["Average Price "].mean()
fp.loc[(fp["Average Price "] > mean_priceavg) & (fp["Food Item "] == "Milk")]
# Out:
#     Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 540    Japan   2018       1       Milk                 1 L          186.24
# 541    Japan   2018       2       Milk                 1 L          186.40
# 542    Japan   2018       3       Milk                 1 L          186.56
# 543    Japan   2018       4       Milk                 1 L          186.72
# 544    Japan   2018       5       Milk                 1 L          186.88
# 545    Japan   2018       6       Milk                 1 L          187.04
# 546    Japan   2018       7       Milk                 1 L          187.20
# 547    Japan   2018       8       Milk                 1 L          187.36
# 548    Japan   2018       9       Milk                 1 L          187.52
# 549    Japan   2018      10       Milk                 1 L          187.68
# 550    Japan   2018      11       Milk                 1 L          187.84
# ...

# %% [markdown]
# - Data Harga Rata-Rata Telor di atas rata-rata

# %%
mean_priceavg = fp["Average Price "].mean()
fp.loc[(fp["Average Price "] > mean_priceavg) & (fp["Food Item "] == "Eggs")]
# Out:
#     Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
#
country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 1140   Canada   2018       1   Potatoes                1 Kg            2.85
# 1141   Canada   2018       2   Potatoes                1 Kg            2.85
# 1142   Canada   2018       3   Potatoes                1 Kg            2.86
# 1143   Canada   2018       4   Potatoes                1 Kg            2.86
# 1144   Canada   2018       5   Potatoes                1 Kg            2.87
# 1145   Canada   2018       6   Potatoes                1 Kg            2.87
# 1146   Canada   2018       7   Potatoes                1 Kg            2.88
# 1147   Canada   2018       8   Potatoes                1 Kg            2.88
# 1148   Canada   2018       9   Potatoes                1 Kg            2.89
# 1149   Canada   2018      10   Potatoes                1 Kg            2.89
# 1150   Canada   2018      11   Potatoes                1 Kg            2.90
# ...

# %% [markdown]
# - 5 data dengan Harga Rata-Rata Tertinggi

# %%
# Sorting 5 Harga Rata-Rata Tertinggi
print("5 data dengan harga rata-rata tertinggi")
fp.sort_values(["Average Price "], ascending=False)[:5]
# Out:
# 5 data dengan harga rata-rata tertinggi
#     Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 719    Japan   2022      12   Potatoes                1 Kg          421.43
# 718    Japan   2022      11   Potatoes                1 Kg          419.67
# 717    Japan   2022      10   Potatoes                1 Kg          417.91
# 716    Japan   2022       9   Potatoes                1 Kg          416.15
# 715    Japan   2022       8   Potatoes                1 Kg          414.39
#
#     Currency   Price in USD  Availability  Quality
# 719      JPY           3.03              1     High
# 718      JPY           3.02              1     High
# 717      JPY           3.01              1     High
# 716      JPY           3.00              1     High
# 715      JPY           2.98              1     High

# %% [markdown]
# - 5 data dengan Harga Rata-Rata Terendah

# %%
# Sorting 5 Harga Rata-Rata Terendah
print("5 data dengan harga rata-rata terendah")
fp.sort_values(["Average Price "], ascending=True)[:5]
# Out:
# 5 data dengan harga rata-rata terendah
#      Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 60  Australia   2018       1       Milk                 1 L            1.22
# 61  Australia   2018       2       Milk                 1 L            1.23
# 62  Australia   2018       3       Milk                 1 L            1.24
# 63  Australia   2018       4       Milk                 1 L            1.25
# 64  Australia   2018       5       Milk                 1 L            1.26
#
#    Currency   Price in USD  Availability  Quality
# 60       AUD          0.82              1     High
# 61       AUD          0.83              1     High
# 62       AUD          0.83              1     High
# 63       AUD          0.84              1     High
# 64       AUD          0.84              1     High

# %% [markdown]
# - 5 data dengan Harga USD Tertinggi

# %%
# Sorting 5 Harga USD Tertinggi
print("5 data dengan harga USD tertinggi")
fp.sort_values(["Price in USD"], ascending=False)[:5]
# Out:
# 5 data dengan harga USD tertinggi
#       Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 179  Australia   2022      12       Eggs        Carton of 12            6.00
# 178  Australia   2022      11       Eggs        Carton of 12            5.91
# 177  Australia   2022      10       Eggs        Carton of 12            5.82
# 176  Australia   2022       9       Eggs        Carton of 12            5.73
# 175  Australia   2022       8       Eggs        Carton of 12            5.64
#
#     Currency   Price in USD  Availability  Quality
# 179       AUD          4.03              1     High
# 178       AUD          3.97              1     High
# 177       AUD          3.91              1     High
# 176       AUD          3.85              1     High
# 175       AUD          3.79              1     High

# %% [markdown]
# - 5 data dengan Harga USD Terendah

# %%
# Sorting 5 Harga Rata-Rata Terendah
print("5 data dengan harga USD terendah")
fp.sort_values(["Price in USD"], ascending=True)[:5]
# Out:
# 5 data dengan harga USD terendah
#          Country   Year   Month  Food Item  Unit of Measurement  \
# 720  South Africa   2018       1      Bread                Loaf
# 721  South Africa   2018       2      Bread                Loaf
# 722  South Africa   2018       3      Bread                Loaf
# 723  South Africa   2018       4      Bread                Loaf
# 724  South Africa   2018       5      Bread                Loaf
#
#      Average Price  Currency   Price in USD  Availability  Quality
# 720           12.57       ZAR          0.69              1   Medium
# 721           12.62       ZAR          0.70              1   Medium
# 722           12.67       ZAR          0.70              1   Medium
# 723           12.73       ZAR          0.70              1   Medium
# 724           12.78       ZAR          0.71              1   Medium

# %% [markdown]
# 5. Visualisasi Data

# %% [markdown]
# a. Perbandingan Kategori

# %% [markdown]
# - Perbandingan Harga Roti dalam USD secara rata-rata dengan Negara pada tahun 2018 (Dengan Bar Chart)

# %%
# Atur data baru yang berisi Year 2018 dan Food item Bread
a = fp.loc[(fp["Year "] == 2018) & (fp["Food Item "]== "Bread")]
aust = a.loc[a["Country "] == "Australia"]
sweden = a.loc[a["Country "] == "Sweden"]
japan = a.loc[a["Country "] == "Japan"]
stfa = a.loc[a["Country "] == "South Africa"]
canada = a.loc[a["Country "] == "Canada"]

#Buat mean USD per negara
meanaust = aust["Price in USD"].mean()
meansw = sweden["Price in USD"].mean()
meanjpn = japan["Price in USD"].mean()
meanstfa = stfa["Price in USD"].mean()
meancanada = canada["Price in USD"].mean()

#Buat DataFrame Baru
datanew = {
    'Country': ['Australia', 'Sweden', 'Japan', 'South Africa', 'Canada'],
    'Mean Price USD': [meanaust, meansw, meanjpn, meanstfa, meancanada]
}

df = pd.DataFrame(datanew)
colors = ['orange', 'blue', 'pink', 'green', 'red']

#Buat Visualisasi Data dengan Bar Chart dengan warna
ax = df.plot(kind="barh",x="Country",y="Mean Price USD", color=colors, legend=True)

#Atur Legenda
ax.legend(['Harga Roti (USD)'], loc='best', title='Legenda')

#Atur Title dan Penamaan Sumbu
ax.set_title('Statistika Harga Roti (USD) Negara pada Tahun 2018')
ax.set_xlabel('Harga Roti')
ax.set_ylabel('Negara')

plt.show()

#Penjelasan
print(f"Berdasarkan Bar Chart, Canada memiliki harga roti (dalam USD) termahal dengan sebesar ${meancanada} lain hal dengan Afrika Selatan yang memiliki harga roti (dalam USD) termurah sebesar ${meanstfa} di tahun 2018. ")
# Out:
# Berdasarkan Bar Chart, Canada memiliki harga roti (dalam USD) termahal dengan sebesar $2.2041666666666666 lain hal dengan Afrika Selatan yang memiliki harga roti (dalam USD) termurah sebesar $0.71 di tahun 2018.

# %% [markdown]
# - Data Harga Kentang (USD) periode 2018-2022 (Dengan Histogram)

# %%
# Buat data mengenai Harga Kentang
a = fp.loc[fp["Food Item "] == "Potatoes"]

# Membuat Histogram
pl = a[["Price in USD"]].plot(kind="hist",bins=[0,0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0],rwidth=0.8)

# Atur Judul Chart dan Penamaan Label sumbu
pl.set_title('Data Harga Kentang (USD)')
pl.set_xlabel('Harga (USD)')
pl.set_ylabel('Frekuensi')

#Atur Legenda
plt.legend(title='Legend', loc='upper left')
plt.show() #Menampilkan


#Penjelasan
print("Berdasarkan Histogram, Harga Kentang (USD) banyak mengalami harga di rentang $2 sampai $2.5 pada periode 2018-2022.")
# Out:
# Berdasarkan Histogram, Harga Kentang (USD) banyak mengalami harga di rentang $2 sampai $2.5 pada periode 2018-2022.

# %% [markdown]
# b. Perbandingan Perubahan terhadap Waktu

# %% [markdown]
# - Fluktuasi Harga Susu (dalam JPY) per Liter di Jepang pada tahun 2019

# %%
# Atur Data Baru dengan negara Jepang, food item milk, year 2018, currency JPY
a = fp.loc[(fp["Country "] == "Japan") & (fp["Food Item "]== "Milk") & (fp["Year "]== 2019)]

# Buat Line Chart
pl= a.plot(kind="line",x="Month ",y="Average Price ")

# Atur Judul Chart dan Penamaan Label sumbu
pl.set_title('Fluktuasi Harga Susu (dalam JPY) di Jepang periode tahun 2019')
pl.set_xlabel('Bulan')
pl.set_ylabel('Harga Susu (JPY)')

#Atur Legenda
plt.legend(title='Legend', loc='upper left')
plt.show() #Menampilkan

#Penjelasan
print("Berdasarkan Line Chart, Harga Susu (dalam JPY) cenderung meningkat. Pada awal bulan, harga meningkat secara perlahan hingga bulan Agustus. Setelah itu, harga mengalami peningkatan drastis hingga bulan Desember")
# Out:
# Berdasarkan Line Chart, Harga Susu (dalam JPY) cenderung meningkat. Pada awal bulan, harga meningkat secara perlahan hingga bulan Agustus. Setelah itu, harga mengalami peningkatan drastis hingga bulan Desember

# %% [markdown]
# - Fluktuasi Harga Pangan (dalam USD) periode 2018-2022 (Dengan Stacked Area Chart)

# %%
# Atur Data Baru per food item dengan tahunnya masing-masing

# Atur Data Food Item Bread dengan tahunnya dan buat rata-rata harga USD
bread18 = fp.loc[(fp["Food Item "]== "Bread") & (fp["Year "]== 2018)]
bread19 = fp.loc[(fp["Food Item "]== "Bread") & (fp["Year "]== 2019)]
bread20 = fp.loc[(fp["Food Item "]== "Bread") & (fp["Year "]== 2020)]
bread21 = fp.loc[(fp["Food Item "]== "Bread") & (fp["Year "]== 2021)]
bread22 = fp.loc[(fp["Food Item "]== "Bread") & (fp["Year "]== 2022)]

meanbread18 = bread18["Price in USD"].mean()
meanbread19 = bread19["Price in USD"].mean()
meanbread20 = bread20["Price in USD"].mean()
meanbread21 = bread21["Price in USD"].mean()
meanbread22 = bread22["Price in USD"].mean()


# Atur Data Food Item Milk dengan tahunnya dan buat rata-rata harga USD
milk18 = fp.loc[(fp["Food Item "]== "Milk") & (fp["Year "]== 2018)]
milk19 = fp.loc[(fp["Food Item "]== "Milk") & (fp["Year "]== 2019)]
milk20 = fp.loc[(fp["Food Item "]== "Milk") & (fp["Year "]== 2020)]
milk21 = fp.loc[(fp["Food Item "]== "Milk") & (fp["Year "]== 2021)]
milk22 = fp.loc[(fp["Food Item "]== "Milk") & (fp["Year "]== 2022)]

meanmilk18 = milk18["Price in USD"].mean()
meanmilk19 = milk19["Price in USD"].mean()
meanmilk20 = milk20["Price in USD"].mean()
meanmilk21 = milk21["Price in USD"].mean()
meanmilk22 = milk22["Price in USD"].mean()

# Atur Data Food Item Eggs dengan tahunnya dan buat rata-rata harga USD
eggs18 = fp.loc[(fp["Food Item "]== "Eggs") & (fp["Year "]== 2018)]
eggs19 = fp.loc[(fp["Food Item "]== "Eggs") & (fp["Year "]== 2019)]
eggs20 = fp.loc[(fp["Food Item "]== "Eggs") & (fp["Year "]== 2020)]
eggs21 = fp.loc[(fp["Food Item "]== "Eggs") & (fp["Year "]== 2021)]
eggs22 = fp.loc[(fp["Food Item "]== "Eggs") & (fp["Year "]== 2022)]

meaneggs18 = eggs18["Price in USD"].mean()
meaneggs19 = eggs19["Price in USD"].mean()
meaneggs20 = eggs20["Price in USD"].mean()
meaneggs21 = eggs21["Price in USD"].mean()
meaneggs22 = eggs22["Price in USD"].mean()


# Atur Data Food Item Potatoes dengan tahunnya
potatoes18 = fp.loc[(fp["Food Item "]== "Potatoes") & (fp["Year "]== 2018)]
potatoes19 = fp.loc[(fp["Food Item "]== "Potatoes") & (fp["Year "]== 2019)]
potatoes20 = fp.loc[(fp["Food Item "]== "Potatoes") & (fp["Year "]== 2020)]
potatoes21 = fp.loc[(fp["Food Item "]== "Potatoes") & (fp["Year "]== 2021)]
potatoes22 = fp.loc[(fp["Food Item "]== "Potatoes") & (fp["Year "]== 2022)]

meanpotatoes18 = potatoes18["Price in USD"].mean()
meanpotatoes19 = potatoes19["Price in USD"].mean()
meanpotatoes20 = potatoes20["Price in USD"].mean()
meanpotatoes21 = potatoes21["Price in USD"].mean()
meanpotatoes22 = potatoes22["Price in USD"].mean()

# Buat DataFrame Baru
data = {
    'Year': ["2018", "2019", "2020", "2021", "2022"],
    'Bread': [meanbread18, meanbread19, meanbread20, meanbread21, meanbread22],
    'Milk': [meanmilk18, meanmilk19, meanmilk20, meanmilk21, meanmilk22],
    'Eggs': [meaneggs18, meaneggs19, meaneggs20, meaneggs21, meaneggs22],
    'Potatoes': [meanpotatoes18, meanpotatoes19, meanpotatoes20, meanpotatoes21, meanpotatoes22]

}

df = pd.DataFrame(data)

# Buat Stacked Area Chart
ax = df.plot(kind="area",x="Year", y=["Bread","Milk","Eggs", "Potatoes"])

#Atur Title dan Penamaan Sumbu
ax.set_title('Fluktuasi Harga Pangan (USD) Negara periode 2018-2022')
ax.set_xlabel('Tahun')
ax.set_ylabel('Harga (USD)')

plt.show()

# Penjelasan
print("Berdasarkan Stacked Area Chart, semua harga pangan mengalami kecenderungan naik harga pada periode 2018-2022. Harga telur meningkat lebih tajam dan menduduki harga termahal, sedangkan harga susu meningkat paling kecil dan menduduki harga termurah dibanding harga pangan lain.")
# Out:
# Berdasarkan Stacked Area Chart, semua harga pangan mengalami kecenderungan naik harga pada periode 2018-2022. Harga telur meningkat lebih tajam dan menduduki harga termahal, sedangkan harga susu meningkat paling kecil dan menduduki harga termurah dibanding harga pangan lain.

# %% [markdown]
# c. Penampilan hierarki dan	hubungan keseluruhan-bagian

# %% [markdown]
# - - Perbandingan Banyaknya Barang Berkualitas Tinggi terhadap Barang Berkualitas Sedang (Dengan Pie Chart)

# %%
# Membuat Pie Chart
colors = ['Green', 'Red']
fp["Quality "].value_counts().plot(kind = "pie", colors=colors, legend=True, autopct='%1.1f%%')

# Menambahkan Legenda
plt.legend(labels=['High', 'Medium'], loc='lower left', title='Legenda')

# Menambahkan Judul Chart
plt.title('Statistika Kualitas Bahan Pangan Tahun 2018-2022')
plt.ylabel('')  # Menghapus y-label
plt.show() # Menampilkan Chart


#Penjelasan
print(
    "Berdasarkan Pie Chart, Barang Berkualitas Tinggi (High) terdapat sebesar 80% dari total barang diproduksi, sedangkan sisanya adalah barang yang berkualitas sedang (medium)"
)
# Out:
# Berdasarkan Pie Chart, Barang Berkualitas Tinggi (High) terdapat sebesar 80% dari total barang diproduksi, sedangkan sisanya adalah barang yang berkualitas sedang (medium)

# %% [markdown]
# - Perbandingan Harga Pangan antar Negara pada tahun 2021 (dengan Stacked Bar Chart)

# %%
# Atur Data untuk tahun 2021
a = fp.loc[(fp["Year "]== 2021)] 

# Atur Data a untuk per negara dengan food itemnya

# Roti dan Harganya
breadaust = a.loc[(a["Food Item "] == "Bread") & (a["Country "] == "Australia")]
breadsweden = a.loc[(a["Food Item "] == "Bread") & (a["Country "] == "Sweden")]
breadjpn = a.loc[(a["Food Item "] == "Bread") & (a["Country "] == "Japan")]
breadstfa = a.loc[(a["Food Item "] == "Bread") & (a["Country "] == "South Africa")]
breadcnd = a.loc[(a["Food Item "] == "Bread") & (a["Country "] == "Canada")]

meanbreadaust = breadaust["Price in USD"].mean()
meanbreadsweden = breadsweden["Price in USD"].mean()
meanbreadjpn = breadjpn["Price in USD"].mean()
meanbreadstfa = breadstfa["Price in USD"].mean()
meanbreadcnd = breadcnd["Price in USD"].mean()

# Susu dan Harganya
milkaust = a.loc[(a["Food Item "] == "Milk") & (a["Country "] == "Australia")]
milksweden = a.loc[(a["Food Item "] == "Milk") & (a["Country "] == "Sweden")]
milkjpn = a.loc[(a["Food Item "] == "Milk") & (a["Country "] == "Japan")]
milkstfa = a.loc[(a["Food Item "] == "Milk") & (a["Country "] == "South Africa")]
milkcnd = a.loc[(a["Food Item "] == "Milk") & (a["Country "] == "Canada")]

meanmilkaust = milkaust["Price in USD"].mean()
meanmilksweden = milksweden["Price in USD"].mean()
meanmilkjpn = milkjpn["Price in USD"].mean()
meanmilkstfa = milkstfa["Price in USD"].mean()
meanmilkcnd = milkcnd["Price in USD"].mean()


# Telur dan Harganya
eggaust = a.loc[(a["Food Item "] == "Eggs") & (a["Country "] == "Australia")]
eggsweden = a.loc[(a["Food Item "] == "Eggs") & (a["Country "] == "Sweden")]
eggjpn = a.loc[(a["Food Item "] == "Eggs") & (a["Country "] == "Japan")]
eggstfa = a.loc[(a["Food Item "] == "Eggs") & (a["Country "] == "South Africa")]
eggcnd = a.loc[(a["Food Item "] == "Eggs") & (a["Country "] == "Canada")]

meaneggaust = eggaust["Price in USD"].mean()
meaneggsweden = eggsweden["Price in USD"].mean()
meaneggjpn = eggjpn["Price in USD"].mean()
meaneggstfa = eggstfa["Price in USD"].mean()
meaneggcnd = eggcnd["Price in USD"].mean()

# Kentang dan Harganya
potaust = a.loc[(a["Food Item "] == "Potatoes") & (a["Country "] == "Australia")]
potsweden = a.loc[(a["Food Item "] == "Potatoes") & (a["Country "] == "Sweden")]
potjpn = a.loc[(a["Food Item "] == "Potatoes") & (a["Country "] == "Japan")]
potstfa = a.loc[(a["Food Item "] == "Potatoes") & (a["Country "] == "South Africa")]
potcnd = a.loc[(a["Food Item "] == "Potatoes") & (a["Country "] == "Canada")]

meanpotaust = potaust["Price in USD"].mean()
meanpotsweden = potsweden["Price in USD"].mean()
meanpotjpn = potjpn["Price in USD"].mean()
meanpotstfa = potstfa["Price in USD"].mean()
meanpotcnd = potcnd["Price in USD"].mean()


# Buat DataFrame Baru

data = {
    'Country': ["Australia", "Sweden", "Japan", "South Africa", "Canada"],
    'Bread': [meanbreadaust, meanbreadsweden, meanbreadjpn, meanbreadstfa, meanbreadcnd],
    'Milk': [meanmilkaust, meanmilksweden, meanmilkjpn, meanmilkstfa, meanmilkcnd],
    'Eggs': [meaneggaust, meaneggsweden, meaneggjpn, meaneggstfa, meaneggcnd],
    'Potatoes': [meanpotaust, meanpotsweden, meanpotjpn, meanpotstfa, meanpotcnd]
}

df = pd.DataFrame(data)

# Buat Stacked Bar Chart
ax = df.plot(kind='barh', x= 'Country', stacked=True, figsize=(10, 6))

#Atur Title dan Penamaan Sumbu
ax.set_title('Perbandingan Harga Pangan antar Negara tahun 2021')
ax.set_xlabel('Harga (USD)')
ax.set_ylabel('Negara')
plt.show()

#Penjelasan
print("Berdasarkan Stacked Bar Chart, Harga Roti dan Susu di Kanada pada tahun 2021 memiliki nilai harga lebih mahal dibanding negara lain. Lalu Harga Telur termahal berada di Swedia dan Harga Kentang termahal berada di Jepang")
# Out:
# Berdasarkan Stacked Bar Chart, Harga Roti dan Susu di Kanada pada tahun 2021 memiliki nilai harga lebih mahal dibanding negara lain. Lalu Harga Telur termahal berada di Swedia dan Harga Kentang termahal berada di Jepang

# %% [markdown]
# d. Plotting Relationship

# %% [markdown]
# - Hubungan Nilai Harga Roti dalam USD dengan Nilai Harga Roti dalam mata uang AUD

# %%
# Atur Data untuk Mata Uang AUD dan Roti
a = fp.loc[(fp["Currency "]== "AUD") & (fp["Food Item "] == "Bread")] 

# Buat Scatter Plot
ax = a.plot(kind="scatter", x="Price in USD", y="Average Price ")

#Atur Title dan Penamaan Sumbu
ax.set_title('Hubungan Nilai Harga Roti dalam USD dengan Nilai Harga Roti dalam mata uang AUD')
ax.set_xlabel('Harga (USD)')
ax.set_ylabel('Harga (AUD)')
plt.show()

# Penjelasan
print("Berdasarkan Scatter Plot, Hubungan antara Nilai Harga Roti Dolar dengan Nilai Harga Roti Mata Uang AUD merupakan korelasi positif karena seiring naik harga Roti dalam Dolar, semakin naik harga Roti dalam mata uang AUD")
# Out:
# Berdasarkan Scatter Plot, Hubungan antara Nilai Harga Roti Dolar dengan Nilai Harga Roti Mata Uang AUD merupakan korelasi positif karena seiring naik harga Roti dalam Dolar, semakin naik harga Roti dalam mata uang AUD

# %% [markdown]
# - Hubungan Nilai Harga Susu dalam USD dengan Nilai Harga Susu dalam mata uang ZAR

# %%
# Atur Data untuk Mata Uang AUD
a = fp.loc[(fp["Currency "]== "ZAR") & (fp["Food Item "] == "Milk")] 

# Buat Scatter Plot
ax = a.plot(kind="scatter", x="Price in USD", y="Average Price ")

#Atur Title dan Penamaan Sumbu
ax.set_title('Hubungan Nilai Harga Susu dalam USD dengan Nilai Harga Susu dalam mata uang ZAR')
ax.set_xlabel('Harga (USD)')
ax.set_ylabel('Harga (ZAR)')
plt.show()

# Penjelasan
print("Berdasarkan Scatter Plot, Hubungan antara Nilai Harga Susu Dolar dengan Nilai Harga Susu Mata Uang ZAR merupakan korelasi positif karena seiring naik harga Susu dalam Dolar, semakin naik harga Susu dalam mata uang ZAR")
# Out:
# Berdasarkan Scatter Plot, Hubungan antara Nilai Harga Susu Dolar dengan Nilai Harga Susu Mata Uang ZAR merupakan korelasi positif karena seiring naik harga Susu dalam Dolar, semakin naik harga Susu dalam mata uang ZAR

# %% [markdown]
# 6. Korelasi

# %% [markdown]
# - Korelasi Nilai Harga Pangan Mata Uang USD dengan Nilai Harga Pangan Mata Uang AUD

# %%
# Atur Data untuk Mata Uang AUD
a = fp.loc[(fp["Currency "]== "AUD")] 

# Mencari Koefisien Korelasi
corr= a["Average Price "].corr(a["Price in USD"])

# Buat Scatter Plot
ax = a.plot(kind="scatter", x="Price in USD", y="Average Price ")

#Atur Title dan Penamaan Sumbu
ax.set_title('Korelasi Nilai Harga Pangan dalam USD dengan Nilai Harga Pangan dalam mata uang AUD')
ax.set_xlabel('Harga (USD)')
ax.set_ylabel('Harga (AUD)')
plt.show()


# Penjelasan
print(f"Koefisien Korelasi: {corr}")
print(f"Berdasarkan Scatter Plot, Korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang AUD memiliki koefisien korelasi sebesar {corr} yang mendekati 1. Dengan nilai koefisien korelasi mendekati 1, maka korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang AUD berbanding lurus")
# Out:
# Koefisien Korelasi: 0.999988645940604
# Berdasarkan Scatter Plot, Korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang AUD memiliki koefisien korelasi sebesar 0.999988645940604 yang mendekati 1. Dengan nilai koefisien korelasi mendekati 1, maka korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang AUD berbanding lurus

# %% [markdown]
# - Korelasi Nilai Harga Pangan Mata Uang USD dengan Nilai Harga Pangan Mata Uang Kr

# %%
# Atur Data untuk Mata Uang Kr
a = fp.loc[(fp["Currency "]== "Kr")] 

# Mencari Koefisien Korelasi
corr= a["Average Price "].corr(a["Price in USD"])

# Buat Scatter Plot
ax = a.plot(kind="scatter", x="Price in USD", y="Average Price ")

#Atur Title dan Penamaan Sumbu
ax.set_title('Korelasi Nilai Harga Pangan dalam USD dengan Nilai Harga Pangan dalam mata uang Kr')
ax.set_xlabel('Harga (USD)')
ax.set_ylabel('Harga (Kr)')
plt.show()


# Penjelasan
print(f"Koefisien Korelasi: {corr}")
print(f"Berdasarkan Scatter Plot, Korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang Kr memiliki koefisien korelasi sebesar {corr} yang mendekati 1. Dengan nilai koefisien korelasi mendekati 1, maka korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang Kr berbanding lurus")
# Out:
# Koefisien Korelasi: 0.9999931019290601
# Berdasarkan Scatter Plot, Korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang Kr memiliki koefisien korelasi sebesar 0.9999931019290601 yang mendekati 1. Dengan nilai koefisien korelasi mendekati 1, maka korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang Kr berbanding lurus

# %% [markdown]
# - Korelasi Nilai Harga Pangan Mata Uang USD dengan Nilai Harga Pangan Mata Uang JPY

# %%
# Atur Data untuk Mata Uang JPY
a = fp.loc[(fp["Currency "]== "Kr")] 

# Mencari Koefisien Korelasi
corr= a["Average Price "].corr(a["Price in USD"])

# Buat Scatter Plot
ax = a.plot(kind="scatter", x="Price in USD", y="Average Price ")

#Atur Title dan Penamaan Sumbu
ax.set_title('Korelasi Nilai Harga Pangan dalam USD dengan Nilai Harga Pangan dalam mata uang JPY')
ax.set_xlabel('Harga (USD)')
ax.set_ylabel('Harga (JPY)')
plt.show()


# Penjelasan
print(f"Koefisien Korelasi: {corr}")
print(f"Berdasarkan Scatter Plot, Korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang JPY memiliki koefisien korelasi sebesar {corr} yang mendekati 1. Dengan nilai koefisien korelasi mendekati 1, maka korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang JPY berbanding lurus")
# Out:
# Koefisien Korelasi: 0.9999931019290601
# Berdasarkan Scatter Plot, Korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang JPY memiliki koefisien korelasi sebesar 0.9999931019290601 yang mendekati 1. Dengan nilai koefisien korelasi mendekati 1, maka korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang JPY berbanding lurus

# %% [markdown]
# - Korelasi Nilai Harga Pangan Mata Uang USD dengan Nilai Harga Pangan Mata Uang ZAR

# %%
# Atur Data untuk Mata Uang ZAR
a = fp.loc[(fp["Currency "]== "ZAR")] 

# Mencari Koefisien Korelasi
corr= a["Average Price "].corr(a["Price in USD"])

# Buat Scatter Plot
ax = a.plot(kind="scatter", x="Price in USD", y="Average Price ")

#Atur Title dan Penamaan Sumbu
ax.set_title('Korelasi Nilai Harga Pangan dalam USD dengan Nilai Harga Pangan dalam mata uang ZAR')
ax.set_xlabel('Harga (USD)')
ax.set_ylabel('Harga (ZAR)')
plt.show()


# Penjelasan
print(f"Koefisien Korelasi: {corr}")
print(f"Berdasarkan Scatter Plot, Korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang ZAR memiliki koefisien korelasi sebesar {corr} yang mendekati 1. Dengan nilai koefisien korelasi mendekati 1, maka korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang ZAR berbanding lurus")
# Out:
# Koefisien Korelasi: 0.9999588128969522
# Berdasarkan Scatter Plot, Korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang ZAR memiliki koefisien korelasi sebesar 0.9999588128969522 yang mendekati 1. Dengan nilai koefisien korelasi mendekati 1, maka korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang ZAR berbanding lurus

# %% [markdown]
# - Korelasi Nilai Harga Pangan Mata Uang USD dengan Nilai Harga Pangan Mata Uang CAD

# %%
# Atur Data untuk Mata Uang CAD
a = fp.loc[(fp["Currency "]== "CAD")] 

# Mencari Koefisien Korelasi
corr= a["Average Price "].corr(a["Price in USD"])

# Buat Scatter Plot
ax = a.plot(kind="scatter", x="Price in USD", y="Average Price ")

#Atur Title dan Penamaan Sumbu
ax.set_title('Korelasi Nilai Harga Pangan dalam USD dengan Nilai Harga Pangan dalam mata uang CAD')
ax.set_xlabel('Harga (USD)')
ax.set_ylabel('Harga (CAD)')
plt.show()


# Penjelasan
print(f"Koefisien Korelasi: {corr}")
print(f"Berdasarkan Scatter Plot, Korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang CAD memiliki koefisien korelasi sebesar {corr} yang mendekati 1. Dengan nilai koefisien korelasi mendekati 1, maka korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang CAD berbanding lurus")
# Out:
# Koefisien Korelasi: 0.9999587221612718
# Berdasarkan Scatter Plot, Korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang CAD memiliki koefisien korelasi sebesar 0.9999587221612718 yang mendekati 1. Dengan nilai koefisien korelasi mendekati 1, maka korelasi antara Nilai Harga Pangan Mata Uang Dolar dengan Nilai Harga Pangan Mata Uang CAD berbanding lurus
